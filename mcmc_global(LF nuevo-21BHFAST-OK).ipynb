# %% [markdown]
# # MCMC with Multiple Likelihoods

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from py21cmmc import mcmc, core, analyse, likelihood

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this tutorial we demonstrate two main ideas: how to use the non-power-spectrum likelihoods provided in ``21CMMlikelihood, and how to use more than one likelihood at a time. The extra likelihoods that we use were called "priors" in previous versions and publications, and they can help break parameter degeneracies in some cases.

# %%
import py21cmmc
py21cmmc.__version__
# Out:
# '1.0.0dev3'

# %%
pip show 21cmFAST
# Out:
# Name: 21cmFAST
# Version: 0.1.dev57+gbf67ddc
# Summary: A semi-numerical cosmological simulation code for the 21cm signal
# Home-page: https://github.com/21cmFAST/21cmFAST
# Author: The 21cmFAST coredev team
# Author-email: 21cmfast.coredev@gmail.com
# License: MIT license
# Location: /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages
# Requires: astropy, attrs, bidict, cached_property, cffi, click, cosmotile, h5py, matplotlib, numpy, pyyaml, scipy
# Required-by: 21cmMC
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Setting up cores and likelihoods

# %% [markdown]
# The various extra likelihoods provided work *best* (but not exclusively) with a Lightcone core, so we will use them in conjunction with a lightcone likelihood. This is because they typically measure the global average of a quantity (either brightness temperature or neutral fraction) as a function of redshift.

# %% [markdown]
# For the core, we take the same as that used in the lightcone MCMC intro:

# %%
CoreLightCone = core.CoreLightConeModule( # All core modules are prefixed by Core* and end with *Module
    redshift = 5.5,              # Lower redshift of the lightcone
    max_redshift = 8.0,          # Approximate maximum redshift of the lightcone (will be exceeded).
    user_params = dict(       
        HII_DIM = 64,         
        BOX_LEN = 160.0,
        N_THREADS= 20
    ),
    z_step_factor=1.04,          # How large the steps between evaluated redshifts are (log).
    regenerate=False,
    nchunks=4
) # For other available options, see the docstring.

# %% [markdown]
# Now we instantiate several different likelihoods, beginning with the basic 1D power spectrum:

# %%
# Now the likelihood...
datafiles = ["data/lightcone_mcmc_data_%s.npz"%i for i in range(4)]
likelihood_ps = likelihood.Likelihood1DPowerLightcone(  # All likelihood modules are prefixed by Likelihood*
    datafile = datafiles,        # All likelihoods have this, which specifies where to write/read data
    logk=False,                  # Should the power spectrum bins be log-spaced?
    min_k=0.1,                   # Minimum k to use for likelihood
    max_k=1.0,                   # Maximum ""
    nchunks = 4,                 # Number of chunks to break the lightcone into
    simulate=True
) # For other available options, see the docstring

likelihood_planck = likelihood.LikelihoodPlanck()  # there are no options here, though some class variables
                                                    # can be set to change the behaviour (eg. tau_mean, tu_sigma)
    
#likelihood_mcgreer = likelihood.LikelihoodNeutralFraction()  # Again, no required options, though the options
                                                              # redshift, xHI_mean, xHI_sigma can be set. By default
                                                              # they evaluate to the McGreer values.
        
#likelihood_greig = likelihood.LikelihoodGreig()

# %% [markdown]
# ## Running MCMC

# %%
model_name = "MultiLikelihoodTest"

chain = mcmc.run_mcmc(
    [CoreLightCone, ], 
    [likelihood_ps, 
     #likelihood_mcgreer, 
     #likelihood_greig,
     likelihood_planck],
    datadir='data',          # Directory for all outputs
    model_name=model_name,   # Filename of main chain output
    params=dict(             # Parameter dict as described above.
        ALPHA = [0.03, 0.01, 0.3, 0.5],
        BETA = [0.7, 0.2, 2, 0.5],
        #L_X_MINI = [40.5, 35.0, 45.0, 3.0],
        #F_ESC7_MIN = [-2.22, -3, 0, 0.5],
        #F_STAR7_MINI = [-1.75, -3, 0, 0.5],
        HII_EFF_FACTOR = [30.0, 10.0, 50.0, 3.0],
        #ION_Tvir_MIN = [4.7, 4, 6, 0.1],
    ), 
    walkersRatio=8,          # The number of walkers will be walkersRatio*nparams
    burninIterations=0,      # Number of iterations to save as burnin. Recommended to leave as zero.
    sampleIterations=500,    # Number of iterations to sample, per walker.
    threadCount=6,           # Number of processes to use in MCMC (best as a factor of walkersRatio)
    continue_sampling=False  # Whether to contine sampling from previous run *up to* sampleIterations.
)
# Out:
# 2025-03-11 11:16:11,038 | WARNING | likelihood.py::_write_data() | File data/lightcone_mcmc_data_0.npz already exists. Moving previous version to data/lightcone_mcmc_data_0.npz.bk
# 2025-03-11 11:16:11,042 | WARNING | likelihood.py::_write_data() | File data/lightcone_mcmc_data_1.npz already exists. Moving previous version to data/lightcone_mcmc_data_1.npz.bk
# 2025-03-11 11:16:11,045 | WARNING | likelihood.py::_write_data() | File data/lightcone_mcmc_data_2.npz already exists. Moving previous version to data/lightcone_mcmc_data_2.npz.bk
# 2025-03-11 11:16:11,047 | WARNING | likelihood.py::_write_data() | File data/lightcone_mcmc_data_3.npz already exists. Moving previous version to data/lightcone_mcmc_data_3.npz.bk
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/outputs.py:1212: UserWarning: global_xHI is deprecated. From now on, use global_xH. Will be removed in v3.1
#   warnings.warn(

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Accessing chain data

# %% [markdown]
# Access the samples object within the chain (see the intro for more details):

# %%
samples = chain.samples

# %% [markdown]
# ### Trace Plot

# %% [markdown]
# Often, for diagnostic purposes, the most useful plot to start with is the trace plot. This enables quick diagnosis of burnin time and walkers that haven't converged. The function in ``py21cmmc`` by default plots the log probability along with the various parameters that were fit. It also supports setting a starting iteration, and a thinning amount.

# %%
analyse.trace_plot(samples, include_lnl=True, start_iter=5, thin=1, colored=False, show_guess=True);
plt.savefig('Trace Plot_Likelihood_3(NO)(21BHFAST).jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Corner Plot

# %%
analyse.corner_plot(samples, start_iter=5);
plt.savefig('corner Plot_Likelihood_3(NO)(21BHFAST).jpg', dpi=300, bbox_inches='tight')
# Out:
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# ## Using the Luminosity Function Likelihood

# %% [markdown]
# Another likelihood which can be important in breaking degeneracies is the ``LikelihoodLuminosityFunction``.
#
# Note that this is commonly used with ``flag_options = {'USE_MASS_DEPENDENT_ZETA': True}`` whose parameterization scales galaxy properties with halo masses.
#
# Luminosity functions at z=6 to 10 from Bouwens et al. (2015; 2016) and Oesch et al. (2018) are available. Alternatively, users can provide other observational data in specific forms and pass the brightness magnitude and corresponding number density of galaxies to the argument ``datafile`` as well as the uncertainties (optional) to ``noisefile`` (see more in the docstring of ``LikelihoodLuminosityFunction`` or the provided data in ``src/py21cmmc/data/LF*.npz``).

# %%
model_name = "LuminosityLikelihood"
redshifts = [6, 7, 8, 10] # redshifts of the provided data
#redshifts = [6] # redshifts of the provided data

chainLF = mcmc.run_mcmc(
    [ core.CoreLuminosityFunction( redshift=z, sigma=0, name='lfz%d'%z) for z in redshifts ], # Assuming no model uncertainties.
    [ likelihood.LikelihoodLuminosityFunction(name='lfz%d'%z) for z in redshifts ], # No need for datafile or noisefile if using the provided data.
    model_name=model_name,   # Filename of main chain output
    params=dict(             # These parameters require flag_options = {'USE_MASS_DEPENDENT_ZETA': True} when running 21cmFAST.

        ALPHA = [0.03, 0.01, 0.3, 0.5],
        BETA = [0.7, 0.2, 2, 0.5],
        L_X_MINI = [40.5, 35.0, 45.0, 3.0],
        F_ESC7_MIN = [-2.22, -3, 0, 0.5],
        F_STAR7_MINI = [-1.75, -3, 0, 0.5], 
        HII_EFF_FACTOR=[30.0, 10.0, 50.0, 3.0],
        ION_Tvir_MIN=[4.7, 4, 6, 0.1],
        #F_STAR10 = [-1.3, -3, 0, 1.0],
        #ALPHA_STAR = [0.5, -0.5, 1.0, 1.0],
        #M_TURN = [8.69897, 8, 10, 1.0],
        #t_STAR = [0.5, 0.01, 1, 0.3],
    ),
    walkersRatio=20,          # The number of walkers will be walkersRatio*nparams
    burninIterations=50,      # Number of iterations to save as burnin. Recommended to leave as zero.
    sampleIterations=1000,   # Number of iterations to sample, per walker.
    threadCount=20,           # Number of processes to use in MCMC (best as a factor of walkersRatio)
    continue_sampling=False  # Whether to contine sampling from previous run *up to* sampleIterations.
)

analyse.corner_plot(chainLF.samples, start_iter=100, include_lnl=False);
plt.savefig('corner Plot LF (21BHFAST).jpg', dpi=300, bbox_inches='tight')
# Out:
# /home/ogarcia/miniconda3/envs/BH_V1/lib/python3.10/site-packages/py21cmfast/inputs.py:519: UserWarning: The USE_INTERPOLATION_TABLES setting has changed in v3.1.2 to be default True. You can likely ignore this warning, but if you relied onhaving USE_INTERPOLATION_TABLES=False by *default*, please set it explicitly. To silence this warning, set it explicitly to True. Thiswarning will be removed in v4.
#   warnings.warn(
# INFO:cosmoHammer:Using CosmoHammer 0.6.1
# INFO:cosmoHammer:Using emcee 2.2.1
# INFO:cosmoHammer:all burnin iterations already completed
# INFO:cosmoHammer:Sampler: <class 'py21cmmc.cosmoHammer.CosmoHammerSampler'>
# configuration:
#   Params: [ 3.00e-02  7.00e-01  4.05e+01 -2.22e+00 -1.75e+00  3.00e+01  4.70e+00]
#   Burnin iterations: 50
#   Samples iterations: 1000
#   Walkers ratio: 20
#   Reusing burn in: True
#   init pos generator: SampleBallPositionGenerator
#   stop criteria: IterationStopCriteriaStrategy
#   storage util: <py21cmmc.cosmoHammer.HDFStorageUtil object at 0x7fd3541f4b80>
# likelihoodComputationChain:
# Core Modules:
#   CoreLuminosityFunction
#   CoreLuminosityFunction
#   CoreLuminosityFunction
#   CoreLuminosityFunction
# Likelihood Modules:
#   LikelihoodLuminosityFunction
#   LikelihoodLuminosityFunction
#   LikelihoodLuminosityFunction
#   LikelihoodLuminosityFunction
#
# INFO:cosmoHammer:start sampling after burn in
# INFO:cosmoHammer:Iteration finished:10
# INFO:cosmoHammer:Iteration finished:20
# INFO:cosmoHammer:Iteration finished:30
# INFO:cosmoHammer:Iteration finished:40
# INFO:cosmoHammer:Iteration finished:50
# INFO:cosmoHammer:Iteration finished:60
# INFO:cosmoHammer:Iteration finished:70
# INFO:cosmoHammer:Iteration finished:80
# INFO:cosmoHammer:Iteration finished:90
# INFO:cosmoHammer:Iteration finished:100
# INFO:cosmoHammer:Iteration finished:110
# INFO:cosmoHammer:Iteration finished:120
# INFO:cosmoHammer:Iteration finished:130
# INFO:cosmoHammer:Iteration finished:140
# INFO:cosmoHammer:Iteration finished:150
# INFO:cosmoHammer:Iteration finished:160
# INFO:cosmoHammer:Iteration finished:170
# INFO:cosmoHammer:Iteration finished:180
# INFO:cosmoHammer:Iteration finished:190
# INFO:cosmoHammer:Iteration finished:200
# INFO:cosmoHammer:Iteration finished:210
# INFO:cosmoHammer:Iteration finished:220
# INFO:cosmoHammer:Iteration finished:230
# INFO:cosmoHammer:Iteration finished:240
# INFO:cosmoHammer:Iteration finished:250
# INFO:cosmoHammer:Iteration finished:260
# INFO:cosmoHammer:Iteration finished:270
# INFO:cosmoHammer:Iteration finished:280
# INFO:cosmoHammer:Iteration finished:290
# INFO:cosmoHammer:Iteration finished:300
# INFO:cosmoHammer:Iteration finished:310
# INFO:cosmoHammer:Iteration finished:320
# INFO:cosmoHammer:Iteration finished:330
# INFO:cosmoHammer:Iteration finished:340
# INFO:cosmoHammer:Iteration finished:350
# INFO:cosmoHammer:Iteration finished:360
# INFO:cosmoHammer:Iteration finished:370
# INFO:cosmoHammer:Iteration finished:380
# INFO:cosmoHammer:Iteration finished:390
# INFO:cosmoHammer:Iteration finished:400
# INFO:cosmoHammer:Iteration finished:410
# INFO:cosmoHammer:Iteration finished:420
# INFO:cosmoHammer:Iteration finished:430
# INFO:cosmoHammer:Iteration finished:440
# INFO:cosmoHammer:Iteration finished:450
# INFO:cosmoHammer:Iteration finished:460
# INFO:cosmoHammer:Iteration finished:470
# INFO:cosmoHammer:Iteration finished:480
# INFO:cosmoHammer:Iteration finished:490
# INFO:cosmoHammer:Iteration finished:500
# INFO:cosmoHammer:Iteration finished:510
# INFO:cosmoHammer:Iteration finished:520
# INFO:cosmoHammer:Iteration finished:530
# INFO:cosmoHammer:Iteration finished:540
# INFO:cosmoHammer:Iteration finished:550
# INFO:cosmoHammer:Iteration finished:560
# INFO:cosmoHammer:Iteration finished:570
# INFO:cosmoHammer:Iteration finished:580
# INFO:cosmoHammer:Iteration finished:590
# INFO:cosmoHammer:Iteration finished:600
# INFO:cosmoHammer:Iteration finished:610
# INFO:cosmoHammer:Iteration finished:620
# INFO:cosmoHammer:Iteration finished:630
# INFO:cosmoHammer:Iteration finished:640
# INFO:cosmoHammer:Iteration finished:650
# INFO:cosmoHammer:Iteration finished:660
# INFO:cosmoHammer:Iteration finished:670
# INFO:cosmoHammer:Iteration finished:680
# INFO:cosmoHammer:Iteration finished:690
# INFO:cosmoHammer:Iteration finished:700
# INFO:cosmoHammer:Iteration finished:710
# INFO:cosmoHammer:Iteration finished:720
# INFO:cosmoHammer:Iteration finished:730
# INFO:cosmoHammer:Iteration finished:740
# INFO:cosmoHammer:Iteration finished:750
# INFO:cosmoHammer:Iteration finished:760
# INFO:cosmoHammer:Iteration finished:770
# INFO:cosmoHammer:Iteration finished:780
# INFO:cosmoHammer:Iteration finished:790
# INFO:cosmoHammer:Iteration finished:800
# INFO:cosmoHammer:Iteration finished:810
# INFO:cosmoHammer:Iteration finished:820
# INFO:cosmoHammer:Iteration finished:830
# INFO:cosmoHammer:Iteration finished:840
# INFO:cosmoHammer:Iteration finished:850
# INFO:cosmoHammer:Iteration finished:860
# INFO:cosmoHammer:Iteration finished:870
# INFO:cosmoHammer:Iteration finished:880
# INFO:cosmoHammer:Iteration finished:890
# INFO:cosmoHammer:Iteration finished:900
# INFO:cosmoHammer:Iteration finished:910
# INFO:cosmoHammer:Iteration finished:920
# INFO:cosmoHammer:Iteration finished:930
# INFO:cosmoHammer:Iteration finished:940
# INFO:cosmoHammer:Iteration finished:950
# INFO:cosmoHammer:Iteration finished:960
# INFO:cosmoHammer:Iteration finished:970
# INFO:cosmoHammer:Iteration finished:980
# INFO:cosmoHammer:Iteration finished:990
# INFO:cosmoHammer:Iteration finished:1000
# INFO:cosmoHammer:sampling done! Took: 7834.8619s
# INFO:cosmoHammer:Mean acceptance fraction:0.2159
